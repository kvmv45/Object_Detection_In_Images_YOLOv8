# %% [markdown]
# <a href="https://colab.research.google.com/github/kvmv45/Object_Detection_In_Images_YOLOv8/blob/main/Object_detection_in_Image_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.8/872.8 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import cv2
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
# Load the YOLOv8 model
model = YOLO('yolov8n.pt')  # You can choose other variants like yolov8s.pt, yolov8m.pt, etc.
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 72.8MB/s]

# %%
def detect_objects(image_path):
    # Load image
    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Perform inference
    results = model.predict(source=img_rgb)

    # Plot results
    plt.imshow(results[0].plot())  # Display the image with bounding boxes
    plt.axis('off')
    plt.show()

# %%
from google.colab import files

uploaded = files.upload()
image_path = next(iter(uploaded))  # Get the uploaded file name
# Out:
#      <input type="file" id="files-05a44235-88b8-46df-914a-46c81571f7e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05a44235-88b8-46df-914a-46c81571f7e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
detect_objects(image_path)
# Out:
# 0: 640x640 17 cars, 86.2ms
# Speed: 4.0ms preprocess, 86.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
from google.colab import files

uploaded = files.upload()
image_path = next(iter(uploaded))  # Get the uploaded file name
# Out:
#      <input type="file" id="files-f85f75dd-63f0-42da-b096-8d6cc8deec3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f85f75dd-63f0-42da-b096-8d6cc8deec3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
detect_objects(image_path)
# Out:
# 0: 544x640 4 persons, 1 sports ball, 73.8ms
# Speed: 2.1ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
